# %%
# imports
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read files
train01 = pd.read_csv('./Data_Files/train_FD001.txt', sep=" ", names=[  
                    "motocicle_id", 
                    "cycles",
                    "setting01",
                    "setting02",
                    "setting03",
                    "tag01",
                    "tag02",
                    "tag03",
                    "tag04",
                    "tag05",
                    "tag06",
                    "tag07",
                    "tag08",
                    "tag09",
                    "tag10",
                    "tag11",
                    "tag12",
                    "tag13",
                    "tag14",
                    "tag15",
                    "tag16",
                    "tag17",
                    "tag18",
                    "tag19",
                    "tag20",
                    "tag21",
                    " ",
                    ""]) # read and make header train_FD001.txt

test01 = pd.read_csv('./Data_Files/test_FD001.txt', sep=" ", names=[  
                    "motocicle_id", 
                    "cycles",
                    "setting01",
                    "setting02",
                    "setting03",
                    "tag01",
                    "tag02",
                    "tag03",
                    "tag04",
                    "tag05",
                    "tag06",
                    "tag07",
                    "tag08",
                    "tag09",
                    "tag10",
                    "tag11",
                    "tag12",
                    "tag13",
                    "tag14",
                    "tag15",
                    "tag16",
                    "tag17",
                    "tag18",
                    "tag19",
                    "tag20",
                    "tag21",
                    " ",
                    ""]) # read and make header test_FD001.txt

rul01 = pd.read_csv('./Data_Files/RUL_FD001.txt', names=['RUL']) # read and make header RUL_FD001.txt

# %%
# show train01 head
train01.head()
# Out:
#    motocicle_id  cycles  setting01  setting02  setting03   tag01   tag02  \
# 0             1       1    -0.0007    -0.0004      100.0  518.67  641.82
# 1             1       2     0.0019    -0.0003      100.0  518.67  642.15
# 2             1       3    -0.0043     0.0003      100.0  518.67  642.35
# 3             1       4     0.0007     0.0000      100.0  518.67  642.35
# 4             1       5    -0.0019    -0.0002      100.0  518.67  642.37
#
#      tag03    tag04  tag05  ...    tag14   tag15  tag16  tag17  tag18  tag19  \
# 0  1589.70  1400.60  14.62  ...  8138.62  8.4195   0.03    392   2388  100.0
# 1  1591.82  1403.14  14.62  ...  8131.49  8.4318   0.03    392   2388  100.0
# 2  1587.99  1404.20  14.62  ...  8133.23  8.4178   0.03    390   2388  100.0
# 3  1582.79  1401.87  14.62  ...  8133.83  8.3682   0.03    392   2388  100.0
# 4  1582.85  1406.22  14.62  ...  8133.80  8.4294   0.03    393   2388  100.0
#
#    tag20    tag21
# 0  39.06  23.4190 NaN NaN
# ...

# %%
# show test01 head
test01.tail(10)
# Out:
#        motocicle_id  cycles  setting01  setting02  setting03   tag01   tag02  \
# 13086           100     189    -0.0003     0.0002      100.0  518.67  643.29
# 13087           100     190    -0.0038     0.0002      100.0  518.67  642.95
# 13088           100     191    -0.0031    -0.0001      100.0  518.67  642.92
# 13089           100     192    -0.0034     0.0001      100.0  518.67  643.05
# 13090           100     193     0.0018     0.0004      100.0  518.67  643.10
# 13091           100     194     0.0049     0.0000      100.0  518.67  643.24
# 13092           100     195    -0.0011    -0.0001      100.0  518.67  643.22
# 13093           100     196    -0.0006    -0.0003      100.0  518.67  643.44
# 13094           100     197    -0.0038     0.0001      100.0  518.67  643.26
# 13095           100     198     0.0013     0.0003      100.0  518.67  642.95
#
#          tag03    tag04  tag05  ...    tag14   tag15  tag16  tag17  tag18  \
# ...

# %%
# show rul01 head
rul01.head()
# Out:
#    RUL
# 0  112
# 1   98
# 2   69
# 3   82
# 4   91

# %%
# creating the header

# train01 header
dftrain01 = pd.DataFrame(train01)
dftrain01 = dftrain01.drop([" ", ""], axis='columns')

# test01 header
dftest01 = pd.DataFrame(test01)
dftest01 = dftest01.drop([" ", ""], axis='columns')

# RUL01 header
dfrul01 = pd.DataFrame(rul01)

# %%
# show dftrain01 head
dftrain01.head()
# Out:
#    motocicle_id  cycles  setting01  setting02  setting03   tag01   tag02  \
# 0             1       1    -0.0007    -0.0004      100.0  518.67  641.82
# 1             1       2     0.0019    -0.0003      100.0  518.67  642.15
# 2             1       3    -0.0043     0.0003      100.0  518.67  642.35
# 3             1       4     0.0007     0.0000      100.0  518.67  642.35
# 4             1       5    -0.0019    -0.0002      100.0  518.67  642.37
#
#      tag03    tag04  tag05  ...   tag12    tag13    tag14   tag15  tag16  \
# 0  1589.70  1400.60  14.62  ...  521.66  2388.02  8138.62  8.4195   0.03
# 1  1591.82  1403.14  14.62  ...  522.28  2388.07  8131.49  8.4318   0.03
# 2  1587.99  1404.20  14.62  ...  522.42  2388.03  8133.23  8.4178   0.03
# 3  1582.79  1401.87  14.62  ...  522.86  2388.08  8133.83  8.3682   0.03
# 4  1582.85  1406.22  14.62  ...  522.19  2388.04  8133.80  8.4294   0.03
#
#    tag17  tag18  tag19  tag20    tag21
# 0    392   2388  100.0  39.06  23.4190
# ...

# %%
# show dftest01 tail
dftest01.tail()
# Out:
#        motocicle_id  cycles  setting01  setting02  setting03   tag01   tag02  \
# 13091           100     194     0.0049     0.0000      100.0  518.67  643.24
# 13092           100     195    -0.0011    -0.0001      100.0  518.67  643.22
# 13093           100     196    -0.0006    -0.0003      100.0  518.67  643.44
# 13094           100     197    -0.0038     0.0001      100.0  518.67  643.26
# 13095           100     198     0.0013     0.0003      100.0  518.67  642.95
#
#          tag03    tag04  tag05  ...   tag12    tag13    tag14   tag15  tag16  \
# 13091  1599.45  1415.79  14.62  ...  520.69  2388.00  8213.28  8.4715   0.03
# 13092  1595.69  1422.05  14.62  ...  521.05  2388.09  8210.85  8.4512   0.03
# 13093  1593.15  1406.82  14.62  ...  521.18  2388.04  8217.24  8.4569   0.03
# 13094  1594.99  1419.36  14.62  ...  521.33  2388.08  8220.48  8.4711   0.03
# 13095  1601.62  1424.99  14.62  ...  521.07  2388.05  8214.64  8.4903   0.03
#
# ...

# %%
# show dfrul01 head
dfrul01.head()
# Out:
#    RUL
# 0  112
# 1   98
# 2   69
# 3   82
# 4   91

# %%
#specify the columns to sum

settingCols = ['setting01',
        'setting02',
        'setting03',
        ]

tagCols = [ "tag01",
        "tag02",
        "tag03",
        "tag04",
        "tag05",
        "tag06",
        "tag07",
        "tag08",
        "tag09",
        "tag10",
        "tag11",
        "tag12",
        "tag13",
        "tag14",
        "tag15",
        "tag16",
        "tag17",
        "tag18",
        "tag19",
        "tag20",
        "tag21",]

#find sum of columns specified 
resultTestSetting = dftest01['somaSetting'] = dftest01[settingCols].sum(axis=1)
resultTestTag = dftest01['somaTag'] = dftest01[tagCols].sum(axis=1)

resultTrainSetting = dftrain01['somaSetting'] = dftrain01[settingCols].sum(axis=1)
resultTrainTag = dftrain01['somaTag'] = dftrain01[tagCols].sum(axis=1)


dftrain01
# Out:
#        motocicle_id  cycles  setting01  setting02  setting03   tag01   tag02  \
# 0                 1       1    -0.0007    -0.0004      100.0  518.67  641.82
# 1                 1       2     0.0019    -0.0003      100.0  518.67  642.15
# 2                 1       3    -0.0043     0.0003      100.0  518.67  642.35
# 3                 1       4     0.0007     0.0000      100.0  518.67  642.35
# 4                 1       5    -0.0019    -0.0002      100.0  518.67  642.37
# ...             ...     ...        ...        ...        ...     ...     ...
# 20626           100     196    -0.0004    -0.0003      100.0  518.67  643.49
# 20627           100     197    -0.0016    -0.0005      100.0  518.67  643.54
# 20628           100     198     0.0004     0.0000      100.0  518.67  643.42
# 20629           100     199    -0.0011     0.0003      100.0  518.67  643.23
# 20630           100     200    -0.0032    -0.0005      100.0  518.67  643.85
#
# ...

# %%
# Estatistics Tests

# select the columns 
eColumns = [ 
                    "cycles",
                    "setting01",
                    "setting02",
                    "setting03",
                    "tag01",
                    "tag02",
                    "tag03",
                    "tag04",
                    "tag05",
                    "tag06",
                    "tag07",
                    "tag08",
                    "tag09",
                    "tag10",
                    "tag11",
                    "tag12",
                    "tag13",
                    "tag14",
                    "tag15",
                    "tag16",
                    "tag17",
                    "tag18",
                    "tag19",
                    "tag20",
                    "tag21",]

# Calcule as medidas de resumo para as colunas selecionadas
resume = dftest01[eColumns].describe()
print(resume)
# Out:
#              cycles     setting01     setting02  setting03     tag01  \
# count  13096.000000  13096.000000  13096.000000    13096.0  13096.00
# mean      76.836515     -0.000011      0.000004      100.0    518.67
# std       53.057749      0.002203      0.000294        0.0      0.00
# min        1.000000     -0.008200     -0.000600      100.0    518.67
# 25%       33.000000     -0.001500     -0.000200      100.0    518.67
# 50%       69.000000     -0.000000     -0.000000      100.0    518.67
# 75%      113.000000      0.001500      0.000300      100.0    518.67
# max      303.000000      0.007800      0.000700      100.0    518.67
#
#               tag02         tag03         tag04         tag05         tag06  \
# count  13096.000000  13096.000000  13096.000000  1.309600e+04  13096.000000
# mean     642.475088   1588.099204   1404.735362  1.462000e+01     21.609701
# std        0.400899      5.003274      6.688309  1.776425e-15      0.001704
# ...

# %%
# Polinomial Regression imports

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error
dftrain01
# Out:
#        motocicle_id  cycles  setting01  setting02  setting03   tag01   tag02  \
# 0                 1       1    -0.0007    -0.0004      100.0  518.67  641.82
# 1                 1       2     0.0019    -0.0003      100.0  518.67  642.15
# 2                 1       3    -0.0043     0.0003      100.0  518.67  642.35
# 3                 1       4     0.0007     0.0000      100.0  518.67  642.35
# 4                 1       5    -0.0019    -0.0002      100.0  518.67  642.37
# ...             ...     ...        ...        ...        ...     ...     ...
# 20626           100     196    -0.0004    -0.0003      100.0  518.67  643.49
# 20627           100     197    -0.0016    -0.0005      100.0  518.67  643.54
# 20628           100     198     0.0004     0.0000      100.0  518.67  643.42
# 20629           100     199    -0.0011     0.0003      100.0  518.67  643.23
# 20630           100     200    -0.0032    -0.0005      100.0  518.67  643.85
#
# ...

# %%
import numpy as np

# Tamanho desejado
tamanho_desejado = 100

# Selecionar aleatoriamente 100 amostras de X
#indices_amostras = np.random.choice(X.shape[0], tamanho_desejado, replace=False)
#X_red = X[indices_amostras]

# %%
# Divida os dados em variáveis independentes (X) e a variável dependente (y)
X = dftrain01[['cycles', 'somaSetting', 'somaTag']]  # Substitua 'Feature1', 'Feature2', 'Feature3' pelos nomes das suas variáveis independentes.

y = dfrul01['RUL']  # Substitua 'VariavelDependente' pelo nome da sua variável dependente.

print("X shape \n",X.shape)
print("y shape \n",y.shape)

'''indices_amostras = np.random.choice(X.shape[0], tamanho_desejado, replace=False)
X_red = X[indices_amostras]

# Divida os dados em conjuntos de treinamento e teste
X_train, X_test, y_train, y_test = train_test_split(X_red, y, test_size=0.2, random_state=42)

print(f'X_train: \n {X_train}')
print(f'y_train: \n {y_train}')

X_trainNumpy = X_train.to_numpy()
y_trainNumpy = y_train.to_numpy()
X_testNumpy = X_test.to_numpy()
y_testNumpy = y_test.to_numpy()

X_trainN = X_trainNumpy.reshape(-1, 1)
y_trainN = y_trainNumpy.reshape(-1, 1)
X_testN = X_testNumpy.reshape(-1, 1)
y_testN = y_testNumpy.reshape(-1, 1)

print(f'X_trainN: \n {X_trainN}')
print(f'y_trainN: \n {y_trainN}')

# Crie o modelo de regressão linear múltipla
modelo = LinearRegression()
modelo.fit(X_trainN, y_trainN)

# Faça previsões com os dados de teste
previsoes = modelo.predict(X_testN)

# Avalie o desempenho do modelo
from sklearn.metrics import r2_score, mean_squared_error

r2 = r2_score(y_testN, previsoes)
mse = mean_squared_error(y_testN, previsoes)

print(f"Coeficiente de Determinação (R-squared): {r2}")
print(f"Erro Quadrático Médio (MSE): {mse}")'''
# Out:
# X shape
#  (20631, 3)
# y shape
#  (100,)
# ...

# %%
# Escolha as colunas que deseja plotar
x = dftest01['motocicle_id']
y = dftest01['setting02']

# Crie o scatter plot
plt.figure(figsize=(8, 6))  # Define o tamanho da figura (opcional)
plt.scatter(x, y, marker='o', color='b', alpha=0.5)

# Defina rótulos dos eixos x e y
plt.xlabel('Rótulo do Eixo X')
plt.ylabel('Rótulo do Eixo Y')

# Defina um título para o gráfico
plt.title('Gráfico de Dispersão')

# Exiba o gráfico
plt.show()
